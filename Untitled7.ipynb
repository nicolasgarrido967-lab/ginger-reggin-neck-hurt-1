# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolasgarrido967-lab/ginger-reggin-neck-hurt-1/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
alunos = ["anderson", "leticia", "nicolas"]
alunos.append("nigger")
print(alunos)
# Out:
# ['anderson', 'leticia', 'nicolas', 'nigger']

# %%
alunos = ["15", "leticia", "mauá"]
print(alunos[0])
# Out:
# 15
