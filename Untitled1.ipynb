# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolasgarrido967-lab/ginger-reggin-neck-hurt-1/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de programação e algoritimos
# * calculo da area
#
# #entrada
# * ler lado1
# * ler lado 2
#
# #processamento
# area = lado1 * lado 2
#
# #saida
# imprimir area

# %%
# calculo de area

# entrada


lado1 = 4

lado2 = 5

name = "Nicolas"

# %%
# processamento


area = lado1 * lado2

# %%
# saida

print (F"total da área: {area}")
# Out:
# total da área: 20

# %%
# Calculo da area do retangulo

# entrada

comprimento = float (input ("digite o comprimento"))
altura = float (input ("digite a altura"))

# processamento

area = comprimento * altura

# saida

print(f" a area do triangulo é igual:{area}")
# Out:
# digite o comprimento1
# digite a altura1
#  a area do triangulo é igual:1.0

# %%
# entrada

numero = int (input("digite um numero:"))

# processamento

dobro = numero * 2


# saida

print (f"o dobro de {numero} é igual a {dobro}")
# Out:
# digite um numero:3
# o dobro de 3 é igual a 6

# %%
#escrever cadastro de usuario
# entrada : nome e idade
# processamento : armazenar dados do usuario
# saida : mostrar uma imagem de boas vindas com nome e idade do usuario

# entrada

nome = str (input("digite seu nome:"))
idade = int (input("digite sua idade:"))

# processamento

# saida

print (f"Olá {nome}, seja bem vindo")
print(f"você tem {idade} anos")
# Out:
# digite seu nome:bradar
# digite sua idade:67
# Olá bradar, seja bem vindo
# você tem 67 anos

# %% [markdown]
# escrever um algoritimo que calcula o triplo

# %%
numero = int (input("digite um numero"))

triplo = numero * 3

print (f"o triplo de {numero} é igual a {triplo}")
# Out:
# digite um numero5
# o triplo de 5 é igual a 15

# %% [markdown]
# escrever um programa que receba o nome do usuario e a idade e mostre uma mensagem com o ano que nasceu

# %% [markdown]
# programa de conversão de temperatura
# # entrada - temperatura em celsius
# # processamento - converter para fahrenheit
# # saida - resultado

# %%
temperatura_celsius = float (input"temperatura_celsius:")
fahrenheit = (temperatura_celsius * 9/5) + 32

print (f"a temperatura é {fahrenheit}")
