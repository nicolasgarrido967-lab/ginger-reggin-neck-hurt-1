# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolasgarrido967-lab/ginger-reggin-neck-hurt-1/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de programação e algoritimos
# * calculo da area
#
# #entrada
# * ler lado1
# * ler lado 2
#
# #processamento
# area = lado1 * lado 2
#
# #saida
# imprimir area

# %%
# calculo de area

# entrada


lado1 = 4

lado2 = 5

name = "Nicolas"

# %%
# processamento


area = lado1 * lado2

# %%
# saida

print (F"total da área: {area}")
# Out:
# total da área: 20
