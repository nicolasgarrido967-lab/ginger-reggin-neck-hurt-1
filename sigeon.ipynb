# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolasgarrido967-lab/ginger-reggin-neck-hurt-1/blob/main/sigeon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# calculo da area do retangulo

# %%
# Calculo da area do retangulo

# entrada

comprimento = float (input ("digite o comprimento"))
altura = float (input ("digite a altura"))

# processamento

area = comprimento * altura

# saida

print(f" a area do triangulo é igual:{area}")

# %%
 entrada

numero = int (input("digite um numero:"))

# processamento

dobro = numero * 2


# saida

print (f"o dobro de {numero} é igual a {dobro}")

# %%
numero = int (input("digite um numero"))

triplo = numero * 3

print (f"o triplo de {numero} é igual a {triplo}")

# %%
#escrever cadastro de usuario
# entrada : nome e idade
# processamento : armazenar dados do usuario
# saida : mostrar uma imagem de boas vindas com nome e idade do usuario

# entrada

nome = str (input("digite seu nome:"))
idade = int (input("digite sua idade:"))

# processamento

# saida

print (f"Olá {nome}, seja bem vindo")
print(f"você tem {idade} anos")
# Out:
# digite seu nome:21
# digite sua idade:12
# Olá 21, seja bem vindo
# você tem 12 anos

# %%
temperatura_celsius = float (input("temperatura em celsius"))
fahrenheit = (temperatura_celsius * 9/5) + 32

print (f"a temperatura é {fahrenheit}")
# Out:
# temperatura em celsius21
# a temperatura é 69.8
