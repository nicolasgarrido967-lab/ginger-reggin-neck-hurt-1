# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolasgarrido967-lab/ginger-reggin-neck-hurt-1/blob/main/renan%20santos%2014.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
aluno = {"nome": "Ana", "idade": 20, "curso": "Engenharia"}
print(aluno)
# Out:
# {'nome': 'Ana', 'idade': 20, 'curso': 'Engenharia'}

# %%
aluno = {"nome": "Carlos", "idade": 22, "curso": "Direito"}

print("Nome:", aluno["nome"])
print("Idade:", aluno["idade"])
print("Curso:", aluno["curso"])
# Out:
# Nome: Carlos
# Idade: 22
# Curso: Direito

# %%
produto = {"nome": "Caderno", "preco": 15.00, "estoque": 50}
produto["preco"] = 18.50
print(produto)
# Out:
# {'nome': 'Caderno', 'preco': 18.5, 'estoque': 50}

# %%
aluno = {"nome": "Beatriz", "idade": 19}
aluno["curso"] = "Medicina"
print(aluno)
# Out:
# {'nome': 'Beatriz', 'idade': 19, 'curso': 'Medicina'}

# %%
filme = {
    "titulo": "Attack On Titan: The Last Attack",
    "ano": 2024,
    "genero": "Mistério e suspense",
    "nota": 9999999.9,
}

print("Título:", filme["titulo"])
print("Ano:", filme["ano"])
print("Gênero:", filme["genero"])
print("Nota:", filme["nota"])
# Out:
# Título: Attack On Titan: The Last Attack
# Ano: 2024
# Gênero: Mistério e suspense
# Nota: 9999999.9

# %% [markdown]
# ***CONJUNTOS***

# %%
numeros = {1, 2, 3, 4, 5}
print(numeros)
# Out:
# {1, 2, 3, 4, 5}

# %%
numeros = {1, 2, 2, 3, 3, 3, 4, 5}
print(numeros)
# Out:
# {1, 2, 3, 4, 5}

# %%
frutas = {"maçã", "banana", "laranja"}
frutas.add("morango")
print(frutas)
# Out:
# {'laranja', 'maçã', 'banana', 'morango'}

# %%
cores = {"vermelho", "azul", "verde", "amarelo"}
cores.remove("verde")
print(cores)
# Out:
# {'vermelho', 'amarelo', 'azul'}

# %%
nomes = ["Yris", "Luna", "Luna", "Maitê", "Yris", "Ravi", "Gael", "Theo", "Theo"]
nomes_unicos = set(nomes)
print(nomes_unicos)
# Out:
# {'Ravi', 'Yris', 'Luna', 'Maitê', 'Theo', 'Gael'}
